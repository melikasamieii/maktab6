# %%
import pandas as pd
from sklearn.datasets import fetch_california_housing

california_housing = fetch_california_housing()

california_housing.data[0]
# Out:
# array([   8.3252    ,   41.        ,    6.98412698,    1.02380952,
#         322.        ,    2.55555556,   37.88      , -122.23      ])

# %%
x = pd.DataFrame(california_housing.data , columns=california_housing.feature_names)

x.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
y = pd.Series(california_housing.target , name= "MedHouseVal")
df= pd.concat([x,y] , axis= 1)

df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
print(df.info())

df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB
# None
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# ...

# %% [markdown]
# nesbat charaka v std , mean che etelati mide ba tvjh b nemoodar v baqie dadeha

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

cov_mat = df.cov()
corr_mat = df.corr()
print(cov_mat)
corr_mat
# Out:
#                 MedInc     HouseAge    AveRooms  AveBedrms    Population  \
# MedInc        3.609323    -2.846140    1.536568  -0.055858  1.040098e+01
# HouseAge     -2.846140   158.396260   -4.772882  -0.463718 -4.222271e+03
# AveRooms      1.536568    -4.772882    6.121533   0.993868 -2.023337e+02
# AveBedrms    -0.055858    -0.463718    0.993868   0.224592 -3.552723e+01
# Population   10.400979 -4222.270582 -202.333712 -35.527225  1.282470e+06
# AveOccup      0.370289     1.724298   -0.124689  -0.030424  8.217120e+02
# Latitude     -0.323860     0.300346    0.562235   0.070575 -2.631378e+02
# Longitude    -0.057765    -2.728244   -0.136518   0.012670  2.263778e+02
# MedHouseVal   1.508475     1.533988    0.433826  -0.025539 -3.221249e+01
#
#                AveOccup    Latitude   Longitude  MedHouseVal
# MedInc         0.370289   -0.323860   -0.057765     1.508475
# HouseAge       1.724298    0.300346   -2.728244     1.533988
# ...

# %%
copydf = df.copy()

copydf["Population"] /= 1000
copydf
print(copydf.cov())
copydf.corr()
# Out:
#                MedInc    HouseAge  AveRooms  AveBedrms  Population  \
# MedInc       3.609323   -2.846140  1.536568  -0.055858    0.010401
# HouseAge    -2.846140  158.396260 -4.772882  -0.463718   -4.222271
# AveRooms     1.536568   -4.772882  6.121533   0.993868   -0.202334
# AveBedrms   -0.055858   -0.463718  0.993868   0.224592   -0.035527
# Population   0.010401   -4.222271 -0.202334  -0.035527    1.282470
# AveOccup     0.370289    1.724298 -0.124689  -0.030424    0.821712
# Latitude    -0.323860    0.300346  0.562235   0.070575   -0.263138
# Longitude   -0.057765   -2.728244 -0.136518   0.012670    0.226378
# MedHouseVal  1.508475    1.533988  0.433826  -0.025539   -0.032212
#
#                AveOccup  Latitude  Longitude  MedHouseVal
# MedInc         0.370289 -0.323860  -0.057765     1.508475
# HouseAge       1.724298  0.300346  -2.728244     1.533988
# AveRooms      -0.124689  0.562235  -0.136518     0.433826
# AveBedrms     -0.030424  0.070575   0.012670    -0.025539
# ...

# %% [markdown]
# cov---> scale , variance
# ba / ---> norm
# ----> corr

# %%
plt.figure(figsize=(8,6))
sns.heatmap(cov_mat, cmap= "viridis")
plt.title("Cov matrix")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(copydf.cov(), cmap= "viridis")
plt.title("Cov matrix Copy")
plt.show()

# %%
sns.heatmap(corr_mat, cmap="coolwarm")
plt.title("Corr matrix")
plt.show()

# %% [markdown]
# b)
# cov
#
# cov(x,y) = 1\n-1 E (x-meanx)(y-mean)
# population>	35682
#
# feature scale--> cov ----> population
#
# corr
#
# -1<p<1
# normalize--> relation
#
# corrmax
# averooms
# letitude
#
# corrmax-
# longitude

# %%
corr_with1 = corr_mat["MedHouseVal"].drop("MedHouseVal").sort_values(ascending=False)
corr_with1
# Out:
# MedInc        0.688075
# AveRooms      0.151948
# HouseAge      0.105623
# AveOccup     -0.023737
# Population   -0.024650
# Longitude    -0.045967
# AveBedrms    -0.046701
# Latitude     -0.144160
# Name: MedHouseVal, dtype: float64

# %% [markdown]
# =1 ----> medinc
# baqie --->0

# %%
top_pos= corr_with1.head(3)
top_pos
# Out:
# MedInc      0.688075
# AveRooms    0.151948
# HouseAge    0.105623
# Name: MedHouseVal, dtype: float64

# %%
top_neg = corr_with1.tail(3)
top_neg
# Out:
# Longitude   -0.045967
# AveBedrms   -0.046701
# Latitude    -0.144160
# Name: MedHouseVal, dtype: float64

# %%
cov_abs = cov_mat.abs().unstack()
corr_abs = corr_mat.abs().unstack()

big_cov= cov_abs.sort_values(ascending=False)
big_cov["Population"]
# Out:
# Population     1.282470e+06
# HouseAge       4.222271e+03
# AveOccup       8.217120e+02
# Latitude       2.631378e+02
# Longitude      2.263778e+02
# AveRooms       2.023337e+02
# AveBedrms      3.552723e+01
# MedHouseVal    3.221249e+01
# MedInc         1.040098e+01
# dtype: float64

# %%
big_corr= corr_abs.sort_values()

big_corr["Population"]
# Out:
# MedInc         0.004834
# MedHouseVal    0.024650
# AveBedrms      0.066197
# AveOccup       0.069863
# AveRooms       0.072213
# Longitude      0.099773
# Latitude       0.108785
# HouseAge       0.296244
# Population     1.000000
# dtype: float64
